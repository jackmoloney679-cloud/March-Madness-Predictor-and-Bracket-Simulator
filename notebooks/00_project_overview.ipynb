# %% [markdown]
# # Project Overview\n\nThis notebook is a lightweight placeholder to document the project structure.\n\n- The full pipeline is implemented in `main.py`.\n- Raw Kaggle CSVs should be placed in `data/raw/` (see `data/raw/README.md`).\n- Outputs are written to `results/`.\n
